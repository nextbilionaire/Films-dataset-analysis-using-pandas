# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Simple Plot
plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 4 
#Simple Plot
plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 8 
#Simple Plot
plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,16) 
y = x ^ 2 
#Simple Plot
plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time Taken (Seconds)") 
plt.ylabel("Distance Covered (Meters)") 
#Simple Plot
plt.plot(x,y)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'r')

# Formatting the line type  
plt.plot(x,y,'>')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'g')

# Formatting the line type  
plt.plot(x,y,'<')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'b')

# Formatting the line type  
plt.plot(x,y,'<')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'w')

# Formatting the line type  
plt.plot(x,y,'<')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'y')

# Formatting the line type  
plt.plot(x,y,'<')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'r')

# Formatting the line type  
plt.plot(x,y,'>') 

# save in pdf formats
plt.savefig('timevsdist.pdf', format='pdf')

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'r')

# Formatting the line type  
plt.plot(x,y,'>') 

# save in pdf formats
plt.savefig('timevsdist.doc', format='doc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-02c25a53b4e9> in <module>
#      16
#      17 # save in pdf formats
# ---> 18 plt.savefig('timevsdist.doc', format='doc')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2148
#    2149         # get canvas object and print method for format
# -> 2150         canvas = self._get_output_canvas(backend, format)
#    2151         print_method = getattr(canvas, 'print_%s' % format)
#    2152
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in _get_output_canvas(self, backend, fmt)
#    2077             return self.switch_backends(canvas_class)
#    2078         # Else report error for unsupported format.
# -> 2079         raise ValueError(
#    2080             "Format {!r} is not supported (supported formats: {})"
#    2081             .format(fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#
# ValueError: Format 'doc' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
#Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 

# Formatting the line colors
plt.plot(x,y,'r')

# Formatting the line type  
plt.plot(x,y,'>') 

# save in pdf formats
plt.savefig('timevsdist.png', format='png')

# %%
import numpy as np 
from matplotlib import pyplot as plt 

x = np.arange(0,10) 
y = x ^ 2 
z = x ^ 3
t = x ^ 4 
# Labeling the Axes and Title
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 
plt.plot(x,y)

#Annotate
plt.annotate(xy=[2,1], s='Second Entry') 
plt.annotate(xy=[4,6], s='Third Entry')
# Out:
# <ipython-input-14-f4584f3eafe6>:15: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(xy=[2,1], s='Second Entry')
# <ipython-input-14-f4584f3eafe6>:16: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(xy=[4,6], s='Third Entry')
# Text(4, 6, 'Third Entry')

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box(grid='True')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box(grid='False')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(15, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box(grid='True')
# Out:
# <AxesSubplot:>

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

data=[{2,3,4,1},{6,3,5,2},{6,3,5,4},{3,7,5,4},{2,8,1,5}]
Index= ['I1', 'I2','I3','I4','I5']
Cols = ['C1', 'C2', 'C3','C4']
df = DataFrame(data, index=Index, columns=Cols)

plt.pcolor(df)
plt.show()

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(80, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(30, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(150, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(500, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)
colors = np.random.rand(0) 
# use the scatter function
plt.scatter(x, y, s=z*1000,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*1000,c=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4290             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4291                 colors = mcolors.to_rgba_array(c)
#    4292             except (TypeError, ValueError) as err:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in <listcomp>(.0)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     262     if not np.iterable(c):
# --> 263         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     264     if len(c) not in [3, 4]:
#
# ValueError: Invalid RGBA argument: 0.10886245605023748
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-0d1b538c3e7c> in <module>
#       8 colors = np.random.rand(40)
#       9 # use the scatter function
# ---> 10 plt.scatter(x, y, s=z*1000,c=colors)
#      11 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4449
#    4450         c, colors, edgecolors = \
# -> 4451             self._parse_scatter_color_args(
#    4452                 c, edgecolors, kwargs, x.size,
#    4453                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4295                 else:
#    4296                     if not valid_shape:
# -> 4297                         raise invalid_shape_exception(c.size, xsize) from err
#    4298                     # Both the mapping *and* the RGBA conversion failed: pretty
#    4299                     # severe failure => one may appreciate a verbose feedback.
#
# ValueError: 'c' argument has 40 elements, which is inconsistent with 'x' and 'y' with size 50.

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*1000,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*100,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*4000,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*2000,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
colors = np.random.rand(50) 
# use the scatter function
plt.scatter(x, y, s=z*1300,c=colors)
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


chart = plt.figure()
chart3d = chart.add_subplot(111, projection='3d')

# Create some test data.
X, Y, Z = axes3d.get_test_data(0.08)

# Plot a wireframe.
chart3d.plot_wireframe(X, Y, Z, color='r',rstride=15, cstride=10)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


chart = plt.figure()
chart3d = chart.add_subplot(111, projection='3d')

# Create some test data.
X, Y, Z = axes3d.get_test_data(0.8)

# Plot a wireframe.
chart3d.plot_wireframe(X, Y, Z, color='r',rstride=15, cstride=10)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


chart = plt.figure()
chart3d = chart.add_subplot(111, projection='3d')

# Create some test data.
X, Y, Z = axes3d.get_test_data(0.08)

# Plot a wireframe.
chart3d.plot_wireframe(X, Y, Z, color='b',rstride=25, cstride=15)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


chart = plt.figure()
chart3d = chart.add_subplot(111, projection='3d')

# Create some test data.
X, Y, Z = axes3d.get_test_data(0.08)

# Plot a wireframe.
chart3d.plot_wireframe(X, Y, Z, color='g',rstride=15, cstride=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=0.8)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-9d566985d543> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import cartopy.crs as ccrs
#       3
#       4 fig = plt.figure(figsize=(15, 10))
#       5 ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=0.8)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-9d566985d543> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import cartopy.crs as ccrs
#       3
#       4 fig = plt.figure(figsize=(15, 10))
#       5 ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
G_dense = np.array([ [0, 2, 1],
                     [2, 0, 0],
                     [1, 0, 0] ])

G_masked = np.ma.masked_values(G_dense, 0)
from scipy.sparse import csr_matrix

G_sparse = csr_matrix(G_dense)
print G_sparse.data
# Out:
#   File "<ipython-input-38-f51dc07b766a>", line 9
#     print G_sparse.data
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(G_sparse.data)?

# %%
G_dense = np.array([ [0, 2, 1],
                     [2, 0, 0],
                     [1, 0, 0] ])

G_masked = np.ma.masked_values(G_dense, 0)
from scipy.sparse import csr_matrix

G_sparse = csr_matrix(G_dense)
print (G_sparse.data)
# Out:
# [2 1 2 1]

# %%
from scipy.sparse.csgraph import csgraph_from_dense
G2_data = np.array
([
   [np.inf, 2, 0 ],
   [2, np.inf, np.inf],
   [0, np.inf, np.inf]
])
G2_sparse = csgraph_from_dense(G2_data, null_value=np.inf)
print (G2_sparse.data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-98653dd01e03> in <module>
#       6    [0, np.inf, np.inf]
#       7 ])
# ----> 8 G2_sparse = csgraph_from_dense(G2_data, null_value=np.inf)
#       9 print (G2_sparse.data)
#
# _tools.pyx in scipy.sparse.csgraph._tools.csgraph_from_dense()
#
# _tools.pyx in scipy.sparse.csgraph._tools.csgraph_masked_from_dense()
#
# ValueError: graph should have two dimensions

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=0.8)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/physical/ne_110m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDB950040> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=1.0)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDCB439F0> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=0.2)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDB3227C0> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='purple', alpha=0.6)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDC9F9040> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='pink', alpha=0.8)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDCC05090> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='lime', alpha=0.8)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDCB6C4F0> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs    

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data

ax.set_extent((60, 150, 55, -25))

ax.stock_img()
ax.coastlines()

ax.tissot(facecolor='red', alpha=0.8)

plt.show()
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\cartopy\mpl\geoaxes.py:761: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001CEDAB5BD10> with the PlateCarree projection.
#   warnings.warn('Approximating coordinate system {!r} with the '
